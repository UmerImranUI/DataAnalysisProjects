# %%
import pandas as pd
df=pd.read_csv("F:\py\pandas\stock_data.csv")
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv("F:\py\pandas\stock_data.csv",skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv("F:\py\pandas\stock_data.csv",header=1)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv("F:\py\pandas\stock_data.csv",header=None)
df
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3   RIL   not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("F:\py\pandas\stock_data.csv",header=None, names=["tickers","eps","revenue","price","people"])
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("F:\py\pandas\stock_data.csv",nrows=3)

# %%
import pandas as pd
df=pd.read_csv("F:\py\pandas\stock_data.csv", na_values=['not available','n.a.'])
df
# Out:
#   GOOGL  27.82   87     845     larry page
# 0   WMT   4.61  484    65.0            NaN
# 1  MSFT  -1.00   85    64.0     bill gates
# 2  RIL     NaN   50  1023.0  mukesh ambani
# 3  TATA   5.60   -1     NaN     ratan tata

# %%
import pandas as pd
df=pd.read_csv("F:\py\pandas\stock_data.csv", na_values={
    'eps':['not available','n.a.'],
    'revenue':['not available','n.a.'],
    'price':['not available','n.a.'],
    'people':['not available','n.a.']
})
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
#datawrangling datamunging

# %%
df. to_csv('new.csv',index= False)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
#creates new file

# %%
df.columns
# Out:
# Index(['GOOGL', '27.82', '87', '845', 'larry page'], dtype='object')

# %%
df. to_csv("new.csv",columns=['GOOGL','larry page'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9584/79676912.py in <module>
# ----> 1 df. to_csv("new.csv",columns=['GOOGL','larry page'])
#
# NameError: name 'df' is not defined

# %%
df. to_csv("new.csv",header=False)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata
