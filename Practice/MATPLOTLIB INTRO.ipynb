# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel=('Day')
plt.ylabel=('Temperature')
plt.title=('Weather')

x=[1,2,3,4,5,6,7]
y=[23,45,12,56,78,23,23]

# %%
plt.plot(x,y, color='green',linewidth=5,linestyle='dotted')
